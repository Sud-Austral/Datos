# %%
import requests
import pandas as pd
import json
import codecs

data = pd.read_csv("Rutas.csv")
data
# Out:
#                          route_long_name    end_date  route_type  \
# 0        Mall Plaza Norte - San Bernardo  2019-12-31           3
# 1        Mall Plaza Norte - San Bernardo  2019-12-31           3
# 2                 Santiago - Puente Alto  2019-12-31           3
# 3                 Santiago - Puente Alto  2019-12-31           3
# 4                   El Cortijo - Mapocho  2019-12-31           3
# ..                                   ...         ...         ...
# 756             (M) Neptuno - La Alianza  2019-12-31           3
# 757             (M) San Pablo - La Reina  2019-12-31           3
# 758             (M) San Pablo - La Reina  2019-12-31           3
# 759  Lomas De Lo Aguirre - (M) Pajaritos  2019-12-31           3
# 760  Lomas De Lo Aguirre - (M) Pajaritos  2019-12-31           3
#
#     route_text_color agency_id route_id route_color  route_desc  \
# 0             FFFFFF        TS      201      0951BC         NaN
# 1             FFFFFF        TS      201      0951BC         NaN
# 2             FFFFFF        TS      205      0951BC         NaN
# 3             FFFFFF        TS      205      0951BC         NaN
# 4             FFFFFF        TS     202c      0951BC         NaN
# ..               ...       ...      ...         ...         ...
# 756           FFFFFF        TS      J04      00929E         NaN
# 757           000000        TS      412      F58220         NaN
# 758           000000        TS      412      F58220         NaN
# 759           FFFFFF        TS      J11      00929E         NaN
# 760           FFFFFF        TS      J11      00929E         NaN
#
#                                             directions route_url  \
# 0    [{'direction_id': 0, 'route_id': '201', 'direc...       NaN
# 1    [{'direction_id': 0, 'route_id': '201', 'direc...       NaN
# 2    [{'direction_id': 1, 'route_id': '205', 'direc...       NaN
# 3    [{'direction_id': 1, 'route_id': '205', 'direc...       NaN
# 4    [{'direction_id': 0, 'route_id': '202c', 'dire...       NaN
# ..                                                 ...       ...
# 756  [{'direction_id': 1, 'route_id': 'J04', 'direc...       NaN
# 757  [{'direction_id': 0, 'route_id': '412', 'direc...       NaN
# 758  [{'direction_id': 0, 'route_id': '412', 'direc...       NaN
# 759  [{'direction_id': 1, 'route_id': 'J11', 'direc...       NaN
# 760  [{'direction_id': 1, 'route_id': 'J11', 'direc...       NaN
#
#     route_short_name  start_date  direction_id direction_headsign  \
# 0                201  2019-07-06             1   Mall Plaza Norte
# 1                201  2019-07-06             1   Mall Plaza Norte
# 2                205  2019-07-06             0        Puente Alto
# 3                205  2019-07-06             0        Puente Alto
# 4               202c  2019-07-08             1         El Cortijo
# ..               ...         ...           ...                ...
# 756              J04  2019-07-06             0         La Alianza
# 757              412  2019-07-06             1      (M) San Pablo
# 758              412  2019-07-06             1      (M) San Pablo
# 759              J11  2019-07-06             0      (M) Pajaritos
# 760              J11  2019-07-06             0      (M) Pajaritos
#
#     direction_name
# 0          Inbound
# 1          Inbound
# 2         Outbound
# 3         Outbound
# 4          Inbound
# ..             ...
# 756       Outbound
# 757        Inbound
# 758        Inbound
# 759       Outbound
# 760       Outbound
#
# [761 rows x 15 columns]

# %%
salida = []
for i in data.head(1).iterrows():
    #print(type(i[1]))
    diccionario = i[1].to_dict()
    #json.get(diccionario)
    for j in eval(diccionario["directions"]):
        aux = diccionario
        for k in j.keys():
            #print(k)
            aux[k] = j[k]
        #print(aux)
        #print("*****************************************************************") 
        salida.append(diccionario)
       
        
print("/////////////////////////////////////")
for i in salida:
    print(i) 
        
        #print(type(diccionario))
# Out:
# /////////////////////////////////////
# {'route_long_name': 'Mall Plaza Norte - San Bernardo', 'end_date': '2019-12-31', 'route_type': 3, 'route_text_color': 'FFFFFF', 'agency_id': 'TS', 'route_id': '201', 'route_color': '0951BC', 'route_desc': nan, 'directions': "[{'direction_id': 0, 'route_id': '201', 'direction_headsign': 'San Bernardo', 'direction_name': 'Outbound'}, {'direction_id': 1, 'route_id': '201', 'direction_headsign': 'Mall Plaza Norte', 'direction_name': 'Inbound'}]", 'route_url': nan, 'route_short_name': '201', 'start_date': '2019-07-06', 'direction_id': 1, 'direction_headsign': 'Mall Plaza Norte', 'direction_name': 'Inbound'}
# {'route_long_name': 'Mall Plaza Norte - San Bernardo', 'end_date': '2019-12-31', 'route_type': 3, 'route_text_color': 'FFFFFF', 'agency_id': 'TS', 'route_id': '201', 'route_color': '0951BC', 'route_desc': nan, 'directions': "[{'direction_id': 0, 'route_id': '201', 'direction_headsign': 'San Bernardo', 'direction_name': 'Outbound'}, {'direction_id': 1, 'route_id': '201', 'direction_headsign': 'Mall Plaza Norte', 'direction_name': 'Inbound'}]", 'route_url': nan, 'route_short_name': '201', 'start_date': '2019-07-06', 'direction_id': 1, 'direction_headsign': 'Mall Plaza Norte', 'direction_name': 'Inbound'}

# %%
data_final = pd.DataFrame(salida)
data_final
# Out:
#                    route_long_name    end_date  route_type route_text_color  \
# 0  Mall Plaza Norte - San Bernardo  2019-12-31           3           FFFFFF
# 1  Mall Plaza Norte - San Bernardo  2019-12-31           3           FFFFFF
#
#   agency_id route_id route_color  route_desc  \
# 0        TS      201      0951BC         NaN
# 1        TS      201      0951BC         NaN
#
#                                           directions  route_url  \
# 0  [{'direction_id': 0, 'route_id': '201', 'direc...        NaN
# 1  [{'direction_id': 0, 'route_id': '201', 'direc...        NaN
#
#   route_short_name  start_date  direction_id direction_headsign direction_name
# 0              201  2019-07-06             1   Mall Plaza Norte        Inbound
# 1              201  2019-07-06             1   Mall Plaza Norte        Inbound

# %%
for i in salida:
    print(i)
# Out:
# {'route_long_name': 'Mall Plaza Norte - San Bernardo', 'end_date': '2019-12-31', 'route_type': 3, 'route_text_color': 'FFFFFF', 'agency_id': 'TS', 'route_id': '201', 'route_color': '0951BC', 'route_desc': nan, 'directions': "[{'direction_id': 0, 'route_id': '201', 'direction_headsign': 'San Bernardo', 'direction_name': 'Outbound'}, {'direction_id': 1, 'route_id': '201', 'direction_headsign': 'Mall Plaza Norte', 'direction_name': 'Inbound'}]", 'route_url': nan, 'route_short_name': '201', 'start_date': '2019-07-06', 'direction_id': 1, 'direction_headsign': 'Mall Plaza Norte', 'direction_name': 'Inbound'}
# {'route_long_name': 'Mall Plaza Norte - San Bernardo', 'end_date': '2019-12-31', 'route_type': 3, 'route_text_color': 'FFFFFF', 'agency_id': 'TS', 'route_id': '201', 'route_color': '0951BC', 'route_desc': nan, 'directions': "[{'direction_id': 0, 'route_id': '201', 'direction_headsign': 'San Bernardo', 'direction_name': 'Outbound'}, {'direction_id': 1, 'route_id': '201', 'direction_headsign': 'Mall Plaza Norte', 'direction_name': 'Inbound'}]", 'route_url': nan, 'route_short_name': '201', 'start_date': '2019-07-06', 'direction_id': 1, 'direction_headsign': 'Mall Plaza Norte', 'direction_name': 'Inbound'}
