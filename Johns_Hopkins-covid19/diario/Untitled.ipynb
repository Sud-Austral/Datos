# %%
import git
import pandas as pd
from datetime import datetime, timedelta

url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/" 
#01-22-2020.csv


inicio = datetime(2020,1,22)
fin    = datetime.now()

lista_fechas = [inicio + timedelta(days=d) for d in range((fin - inicio).days + 1)] 
for i in lista_fechas:
    #print(i.strftime("%m-%d-%Y.csv"))
    nombre = i.strftime("%m-%d-%Y.csv")
    try:
        pd.read_csv(url + nombre).to_csv(nombre,index=False)
        u
# Out:
# 01-22-2020.csv
# 01-23-2020.csv
# 01-24-2020.csv
# 01-25-2020.csv
# 01-26-2020.csv
# 01-27-2020.csv
# 01-28-2020.csv
# 01-29-2020.csv
# 01-30-2020.csv
# 01-31-2020.csv
# 02-01-2020.csv
# 02-02-2020.csv
# 02-03-2020.csv
# 02-04-2020.csv
# 02-05-2020.csv
# 02-06-2020.csv
# 02-07-2020.csv
# 02-08-2020.csv
# 02-09-2020.csv
# 02-10-2020.csv
# 02-11-2020.csv
# 02-12-2020.csv
# 02-13-2020.csv
# 02-14-2020.csv
# 02-15-2020.csv
# 02-16-2020.csv
# 02-17-2020.csv
# 02-18-2020.csv
# 02-19-2020.csv
# 02-20-2020.csv
# 02-21-2020.csv
# 02-22-2020.csv
# 02-23-2020.csv
# 02-24-2020.csv
# 02-25-2020.csv
# 02-26-2020.csv
# 02-27-2020.csv
# 02-28-2020.csv
# 02-29-2020.csv
# 03-01-2020.csv
# 03-02-2020.csv
# 03-03-2020.csv
# 03-04-2020.csv
# 03-05-2020.csv
# 03-06-2020.csv
# 03-07-2020.csv
# 03-08-2020.csv
# 03-09-2020.csv
# 03-10-2020.csv
# 03-11-2020.csv
# 03-12-2020.csv
# 03-13-2020.csv
# 03-14-2020.csv
# 03-15-2020.csv
# 03-16-2020.csv
# 03-17-2020.csv
# 03-18-2020.csv
# 03-19-2020.csv
# 03-20-2020.csv
# 03-21-2020.csv
# 03-22-2020.csv
# 03-23-2020.csv
# 03-24-2020.csv
# 03-25-2020.csv
# 03-26-2020.csv
# 03-27-2020.csv
# 03-28-2020.csv
# 03-29-2020.csv
# 03-30-2020.csv
# 03-31-2020.csv
