# %%
import git
repo = git.Repo("")
repo.git.execute('git ls-files -z')
#'ls-files -z | xargs -0 -n1 -I{} -- git log -1 --format="%ai {}" {}'
# Out:
# '.gitattributes\x00.gitignore\x00ASYNCRONO.ipynb\x00Actualizar - copia.py\x00Actualizar.py\x00All/All.csv\x00All/All.ipynb\x00All/All.xlsx\x00All/test.xlsx\x00Chile/Legacy/covid19_chile.csv\x00Chile/Legacy/covid19_chile.xlsx\x00Chile/Legacy/covid19_chileIVAN.csv\x00Chile/Legacy/covid19_chileOLD.csv\x00Chile/Legacy/covid19_comunas.csv\x00Chile/MinCiencia/Principal.csv\x00Chile/MinCiencia/Producto1.csv\x00Chile/MinCiencia/Producto2.csv\x00Chile/MinCiencia/Producto3.csv\x00Chile/MinCiencia/Producto4.csv\x00Chile/MinCiencia/Producto5.csv\x00Chile/MinCiencia/Untitled.ipynb\x00Chile/README.md\x00Chile/Untitled.ipynb\x00Chile/covid19_chile.csv\x00Chile/covid19_chile.xlsx\x00Chile/covid19_chileIVAN.csv\x00Chile/covid19_chileOLD.csv\x00Chile/covid19_chile_old.csv\x00Chile/covid19_comunas.csv\x00Chile/lkink.txt\x00Data Analysis - Material de estudio Previo.pdf\x00EarlyAlert/Current_Coronavirus_Cases_and_Deaths.07-04-2020_11-29-06csv\x00EarlyAlert/Current_Coronavirus_Cases_and_Deaths.07-04-2020
# ...

# %%
repo = git.Repo("")
for commit in list(repo.iter_commits()):
    print(type(commit)) 
    print("*********************************")
# Out:
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# *********************************
# <class 'git.objects.commit.Commit'>
# ...

# %%
import subprocess
p = subprocess.check_output(['git ls-files -z | xargs -0 -n1 -I{} -- git log -1 --format="%ai {}" {} | sort'],cwd = "",shell=True) 
#cwd = change working directory   
print(p)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-6109eacb3ddd> in <module>
#       1 import subprocess
# ----> 2 p = subprocess.check_output(['git ls-files -z | xargs -0 -n1 -I{} -- git log -1 --format="%ai {}" {} | sort'],cwd = "",shell=True)
#       3 #cwd = change working directory
#       4 print(p)
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     393
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#     397
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     470         kwargs['stderr'] = PIPE
#     471
# --> 472     with Popen(*popenargs, **kwargs) as process:
#     473         try:
# ...
