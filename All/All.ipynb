# %%
import pandas as pd

data_paises = pd.read_csv("../InformacionGeneral/Internacional/Detalle_paises.csv")
del data_paises["WORLD_SN"]
del data_paises["ECDC_SN"]
del data_paises["OURWOR_SN"]
del data_paises["JHONH_SN"]
del data_paises["Early_SN"]

data_woldmeter = pd.read_csv("../worldometers.info/worldometers.csv")
columna_woldmeter = data_woldmeter.columns[1:]

for i in columna_woldmeter:
    data_woldmeter[i+"Worldmeter"] = data_woldmeter[i]
    del data_woldmeter[i]
    
merged_left = pd.merge(left=data_paises, right=data_woldmeter, how='left', left_on='WORLDM_Country,Other', right_on='Country,Other')

#data_europa = pd.read_csv("../ecdc.europa/ecdc_europa.csv")
#data_europa
data_ourworld_con = pd.read_csv("../ourworldindata.org/total-cases-covid-19.csv")
data_ourworld_dea = pd.read_csv("../ourworldindata.org/total-deaths-covid-19.csv")
#data_ourworld["Entity"].unique()
#data_ourworld
paises = []
confirmados = []
muertes = []
for i in data_ourworld_con["Entity"].unique():
    maximoConfirmado = max(data_ourworld_con[data_ourworld_con["Entity"] == i]["Total confirmed cases of COVID-19 (cases)"])
    maximoMuerte = max(data_ourworld_dea[data_ourworld_dea["Entity"] == i]["Total confirmed deaths due to COVID-19 (deaths)"])
    #print(i + " " + str(maximo))
    paises.append(i)
    confirmados.append(maximoConfirmado)
    muertes.append(maximoMuerte)

data_ourworld = pd.DataFrame({
    "paises": paises,
    "confirmadoOURWORLD":confirmados,
    "muertosOURWORLD": muertes    
}
)
merged_left = pd.merge(left=merged_left, right=data_ourworld, how='left', left_on='OURWORLD_Entity', right_on='paises')
del merged_left["paises"] 


data_jhon = pd.read_csv("../Johns_Hopkins-covid19/diario/ultimoRegistro.csv")
data_jhon

paises = []
confirmados = []
muertes = []
recuperados = []
activos = []
for i in data_jhon["Country_Region"].unique():
    maximoConfirmado = sum(data_jhon[data_jhon["Country_Region"] == i]["Confirmed"])
    maximoMuerte = sum(data_jhon[data_jhon["Country_Region"] == i]["Deaths"])
    maximoRecuperado = sum(data_jhon[data_jhon["Country_Region"] == i]["Recovered"])
    maximoActivo = sum(data_jhon[data_jhon["Country_Region"] == i]["Active"])
    #print(i + " " + str(maximo))
    paises.append(i)
    confirmados.append(maximoConfirmado)
    muertes.append(maximoMuerte)
    recuperados.append(maximoRecuperado)
    activos.append(maximoActivo)
    
data_jhon_salida = pd.DataFrame({
    "paises": paises,
    "confirmadoJHON":confirmados,
    "muertosJHON": muertes,
    "recuperadosJHON": recuperados,
    "activosJHON": activos
}
)
merged_left = pd.merge(left=merged_left, right=data_jhon_salida, how='left', left_on='JHONH_Country/Region', right_on='paises')
del merged_left["paises"] 
merged_left
# Out:
#       ID                                Nombre Español  \
# 0      1                                    Afganistán
# 1      2                                       Albania
# 2      3                                      Alemania
# 3      4                                       Andorra
# 4      5                                        Angola
# ..   ...                                           ...
# 250  251  Islas Ultramarinas Menores de Estados Unidos
# 251  252                                         Åland
# 252  253                      Crucero Diamond Princess
# 253  254                            Crucero MS Zaandam
# 254  255    Casos en un transporte internacional Japón
#
#                                    Nombre Ingles    region  \
# 0                                    Afghanistan      Asia
# 1                                        Albania    Europe
# 2                                        Germany    Europe
# 3                                        Andorra    Europe
# 4                                         Angola    Africa
# ..                                           ...       ...
# 250         United States Minor Outlying Islands   Oceania
# 251                                Åland Islands    Europe
# 252                             Diamond Princess  Americas
# 253                                   MS Zaandam    Europe
# 254  Cases on an international conveyance  Japan      Asia
#
#                           sub-region intermediate-region alpha-2 alpha-3  \
# 0                      Southern Asia                 NaN      AF     AFG
# 1                    Southern Europe                 NaN      AL     ALB
# 2                     Western Europe                 NaN      DE     DEU
# 3                    Southern Europe                 NaN      AD     AND
# 4                 Sub-Saharan Africa       Middle Africa      AO     AGO
# ..                               ...                 ...     ...     ...
# 250                       Micronesia                 NaN      UM     UMI
# 251                  Northern Europe                 NaN      AX     ALA
# 252  Latin America and the Caribbean           Caribbean      BS     BHS
# 253                   Western Europe                 NaN      NL     NLD
# 254                     Eastern Asia                 NaN      JP     JPN
#
#      Latitude (average)  Longitude (average)  ... Tot Cases/1M popWorldmeter  \
# 0             33.000000            65.000000  ...                        7.0
# 1             41.000000            20.000000  ...                      106.0
# 2             51.000000             9.000000  ...                     1064.0
# 3             42.500000             1.600000  ...                     5682.0
# 4            -12.500000            18.500000  ...                        0.2
# ..                  ...                  ...  ...                        ...
# 250           19.283300           166.600000  ...                        NaN
# 251           60.193667            19.874097  ...                        NaN
# 252           32.297500           -64.801389  ...                        NaN
# 253           51.916667             4.500000  ...                        NaN
# 254           36.000000           138.000000  ...                        NaN
#
#     Deaths/1M popWorldmeter  Reported1st caseWorldmeter Primer casoWorldmeter  \
# 0                      0.20                      Feb 23            23-02-2020
# 1                      6.00                      Mar 07            07-03-2020
# 2                     14.00                      Jan 26            26-01-2020
# 3                    207.00                      Mar 01            01-03-2020
# 4                      0.06                      Mar 19            19-03-2020
# ..                      ...                         ...                   ...
# 250                     NaN                         NaN                   NaN
# 251                     NaN                         NaN                   NaN
# 252                     NaN                      Feb 04            04-02-2020
# 253                     NaN                      Mar 26            26-03-2020
# 254                     NaN                         NaN                   NaN
#
#     confirmadoOURWORLD muertosOURWORLD confirmadoJHON muertosJHON  \
# 0                235.0             4.0          273.0         6.0
# 1                277.0            16.0          277.0        16.0
# 2              73522.0           872.0        84794.0      1107.0
# 3                428.0            15.0          428.0        15.0
# 4                  8.0             2.0            8.0         2.0
# ..                 ...             ...            ...         ...
# 250                NaN             NaN            NaN         NaN
# 251                NaN             NaN            NaN         NaN
# 252                NaN             NaN          712.0        11.0
# 253                NaN             NaN            9.0         2.0
# 254                NaN             NaN            NaN         NaN
#
#     recuperadosJHON activosJHON
# 0              10.0       257.0
# 1              76.0       185.0
# 2           22440.0     61247.0
# 3              10.0       403.0
# 4               1.0         5.0
# ..              ...         ...
# 250             NaN         NaN
# 251             NaN         NaN
# 252           619.0        82.0
# 253             0.0         7.0
# 254             NaN         NaN
#
# [255 rows x 47 columns]

# %%
data_early = pd.read_csv("../EarlyAlert/Current_Coronavirus_Cases_and_Deaths.csv")
#data_early.to_excel("test.xlsx")
data_early

paises = []
confirmados = []
muertes = []
recuperados = []
activos = []
for i in data_jhon["Country_Region"].unique():
    maximoConfirmado = sum(data_jhon[data_jhon["Country_Region"] == i]["Confirmed"])
    maximoMuerte = sum(data_jhon[data_jhon["Country_Region"] == i]["Deaths"])
    maximoRecuperado = sum(data_jhon[data_jhon["Country_Region"] == i]["Recovered"])
    maximoActivo = sum(data_jhon[data_jhon["Country_Region"] == i]["Active"])
    #print(i + " " + str(maximo))
    paises.append(i)
    confirmados.append(maximoConfirmado)
    muertes.append(maximoMuerte)
    recuperados.append(maximoRecuperado)
    activos.append(maximoActivo)
# Out:
#                                 NAME                 COUNTRY  \
# 0     Federacija Bosna i Hercegovina  Bosnia and Herzegovina
# 1                           Budapest                 Hungary
# 2                         Kermanshah                    Iran
# 3                          Quaratine             South Korea
# 4                            B?o-B?o                   Chile
# ...                              ...                     ...
# 5758                         Manyara                Tanzania
# 5759                            Mara                Tanzania
# 5760                           Mbeya                Tanzania
# 5761                 Mjini Magharibi                Tanzania
# 5762                 Mjini Magharibi                Tanzania
#
#                                              ISO_CODE ISO_CC  \
# 0                                               BABIH     BA
# 1     https://koronavirus.gov.hu/terkepek/fertozottek     HU
# 2                                 https://en.irna.ir/     IR
# 3               http://ncov.mohw.go.kr/index_main.jsp     KR
# 4                                                CLBI     CL
# ...                                               ...    ...
# 5758                                             TZ26     TZ
# 5759                                             TZ13     TZ
# 5760                                             TZ14     TZ
# 5761                                             TZ15     TZ
# 5762                                             TZ15     TZ
#
#               ADMINTYPE              COUNTRYAFF      CONTINENT  \
# 0     Autonomous Entity  Bosnia and Herzegovina         Europe
# 1          Capital City                 Hungary         Europe
# 2              Province                    Iran           Asia
# 3     Metropolitan City             South Korea           Asia
# 4                Region                   Chile  South America
# ...                 ...                     ...            ...
# 5758             Region                Tanzania         Africa
# 5759             Region                Tanzania         Africa
# 5760             Region                Tanzania         Africa
# 5761             Region                Tanzania         Africa
# 5762             Region                Tanzania         Africa
#
#               LAND_TYPE  Confirmed  Deaths           x          y  ObjectId
# 0          Primary land      243.0    10.0   17.536059  44.108097         1
# 1          Primary land      243.0    21.0   19.109246  47.484519         2
# 2          Primary land      243.0     2.0   46.649114  34.468749         3
# 3          Primary land      242.0     0.0  128.569235  35.834741         4
# 4          Primary land      240.0     2.0  -72.259136 -37.184463         5
# ...                 ...        ...     ...         ...        ...       ...
# 5758       Primary land        NaN     NaN   36.505751  -4.636646      5759
# 5759       Primary land        NaN     NaN   34.139347  -1.722950      5760
# 5760       Primary land        NaN     NaN   33.359456  -8.231195      5761
# 5761       Small island        NaN     NaN   39.214269  -6.271229      5762
# 5762  Very small island        NaN     NaN   39.207102  -6.221108      5763
#
# [5763 rows x 13 columns]

# %%
data_ourworld
# Out:
#           paises  confirmadoOURWORLD  muertosOURWORLD
# 0    Afghanistan                 235                4
# 1        Albania                 277               16
# 2        Algeria                 847               58
# 3        Andorra                 428               15
# 4         Angola                   8                2
# ..           ...                 ...              ...
# 199    Venezuela                 144                3
# 200      Vietnam                 239                0
# 201        World             1000249            51515
# 202       Zambia                  39                1
# 203     Zimbabwe                   8                1
#
# [204 rows x 3 columns]
