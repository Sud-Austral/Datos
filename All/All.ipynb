# %%
import pandas as pd

data_paises = pd.read_csv("../InformacionGeneral/Internacional/Detalle_paises.csv")
del data_paises["WORLD_SN"]
del data_paises["ECDC_SN"]
del data_paises["OURWOR_SN"]
del data_paises["JHONH_SN"]
del data_paises["Early_SN"]

data_woldmeter = pd.read_csv("../worldometers.info/worldometers.csv")
columna_woldmeter = data_woldmeter.columns[1:]

for i in columna_woldmeter:
    data_woldmeter[i+"Worldmeter"] = data_woldmeter[i]
    del data_woldmeter[i]
    
merged_left = pd.merge(left=data_paises, right=data_woldmeter, how='left', left_on='WORLDM_Country,Other', right_on='Country,Other')

#data_europa = pd.read_csv("../ecdc.europa/ecdc_europa.csv")
#data_europa
data_ourworld_con = pd.read_csv("../ourworldindata.org/total-cases-covid-19.csv")
data_ourworld_dea = pd.read_csv("../ourworldindata.org/total-deaths-covid-19.csv")
#data_ourworld["Entity"].unique()
#data_ourworld
paises = []
confirmados = []
muertes = []
for i in data_ourworld_con["Entity"].unique():
    maximoConfirmado = max(data_ourworld_con[data_ourworld_con["Entity"] == i]["Total confirmed cases of COVID-19 (cases)"])
    maximoMuerte = max(data_ourworld_dea[data_ourworld_dea["Entity"] == i]["Total confirmed deaths due to COVID-19 (deaths)"])
    #print(i + " " + str(maximo))
    paises.append(i)
    confirmados.append(maximoConfirmado)
    muertes.append(maximoMuerte)

data_ourworld = pd.DataFrame({
    "paises": paises,
    "confirmadoOURWORLD":confirmados,
    "muertosOURWORLD": muertes    
}
)
merged_left = pd.merge(left=merged_left, right=data_ourworld, how='left', left_on='OURWORLD_Entity', right_on='paises')
del merged_left["paises"] 


data_jhon = pd.read_csv("../Johns_Hopkins-covid19/diario/ultimoRegistro.csv")
data_jhon

paises = []
confirmados = []
muertes = []
recuperados = []
activos = []
for i in data_jhon["Country_Region"].unique():
    maximoConfirmado = sum(data_jhon[data_jhon["Country_Region"] == i]["Confirmed"])
    maximoMuerte = sum(data_jhon[data_jhon["Country_Region"] == i]["Deaths"])
    maximoRecuperado = sum(data_jhon[data_jhon["Country_Region"] == i]["Recovered"])
    maximoActivo = sum(data_jhon[data_jhon["Country_Region"] == i]["Active"])
    #print(i + " " + str(maximo))
    paises.append(i)
    confirmados.append(maximoConfirmado)
    muertes.append(maximoMuerte)
    recuperados.append(maximoRecuperado)
    activos.append(maximoActivo)
    
data_jhon_salida = pd.DataFrame({
    "paises": paises,
    "confirmadoJHON":confirmados,
    "muertosJHON": muertes,
    "recuperadosJHON": recuperados,
    "activosJHON": activos
}
)
merged_left = pd.merge(left=merged_left, right=data_jhon_salida, how='left', left_on='JHONH_Country/Region', right_on='paises')
del merged_left["paises"] 
merged_left
# Out:
#       ID                              Nombre Español  \
# 0      1                                  Afganistán
# 1      2                                     Albania
# 2      3                                    Alemania
# 3      4                                     Andorra
# 4      5                                      Angola
# ..   ...                                         ...
# 230  231                                      Jersey
# 231  232                              Islas Malvinas
# 232  233                    Crucero Diamond Princess
# 233  234                          Crucero MS Zaandam
# 234  235  Casos en un transporte internacional Japón
#
#                                    Nombre Ingles  \
# 0                                    Afghanistan
# 1                                        Albania
# 2                                        Germany
# 3                                        Andorra
# 4                                         Angola
# ..                                           ...
# 230                                       Jersey
# 231                             Falkland Islands
# 232                             Diamond Princess
# 233                                   MS Zaandam
# 234  Cases on an international conveyance  Japan
#
#                             WORLDM_Country,Other  \
# 0                                    Afghanistan
# 1                                        Albania
# 2                                        Germany
# 3                                        Andorra
# 4                                         Angola
# ..                                           ...
# 230                                       Jersey
# 231                             Falkland Islands
# 232                             Diamond Princess
# 233                                   MS Zaandam
# 234  Cases on an international conveyance  Japan
#
#                    ECDC_countriesAndTerritories  \
# 0                                   Afghanistan
# 1                                       Albania
# 2                                         Ghana
# 3                                       Andorra
# 4                                        Angola
# ..                                          ...
# 230                                      Jersey
# 231                 Falkland_Islands_(Malvinas)
# 232                            Diamond Princess
# 233                                     Myanmar
# 234  Cases_on_an_international_conveyance_Japan
#
#                                  OURWORLD_Entity  \
# 0                                    Afghanistan
# 1                                        Albania
# 2                                        Germany
# 3                                        Andorra
# 4                                         Angola
# ..                                           ...
# 230                                       Jersey
# 231                             Falkland Islands
# 232                             Diamond Princess
# 233                                   MS Zaandam
# 234  Cases on an international conveyance  Japan
#
#                             JHONH_Country/Region  \
# 0                                    Afghanistan
# 1                                        Albania
# 2                                        Germany
# 3                                        Andorra
# 4                                         Angola
# ..                                           ...
# 230                                       Jersey
# 231                             Falkland Islands
# 232                             Diamond Princess
# 233                                   MS Zaandam
# 234  Cases on an international conveyance  Japan
#
#                                    Early_COUNTRY  \
# 0                                    Afghanistan
# 1                                        Albania
# 2                                        Germany
# 3                                        Andorra
# 4                                         Angola
# ..                                           ...
# 230                                       Jersey
# 231                             Falkland Islands
# 232                             Diamond Princess
# 233                                   MS Zaandam
# 234  Cases on an international conveyance  Japan
#
#                                         Tipo  \
# 0                           Estado Soberanos
# 1                           Estado Soberanos
# 2                           Estado Soberanos
# 3                           Estado Soberanos
# 4                           Estado Soberanos
# ..                                       ...
# 230  Territorio asociado a estados soberanos
# 231  Territorio asociado a estados soberanos
# 232                                    Otros
# 233                                    Otros
# 234                                    Otros
#
#                                    Nombre común  ...  \
# 0                                    Afganistán  ...
# 1                                       Albania  ...
# 2                                      Alemania  ...
# 3                                       Andorra  ...
# 4                                        Angola  ...
# ..                                          ...  ...
# 230                                      Jersey  ...
# 231                              Islas Malvinas  ...
# 232                    Crucero Diamond Princess  ...
# 233                          Crucero MS Zaandam  ...
# 234  Casos en un transporte internacional Japón  ...
#
#     Tot Cases/1M popWorldmeter Deaths/1M popWorldmeter  \
# 0                          7.0                    0.20
# 1                         96.0                    6.00
# 2                       1012.0                   13.00
# 3                       5539.0                  194.00
# 4                          0.2                    0.06
# ..                         ...                     ...
# 230                        NaN                     NaN
# 231                        NaN                     NaN
# 232                        NaN                     NaN
# 233                        NaN                     NaN
# 234                        NaN                     NaN
#
#     Reported1st caseWorldmeter Primer casoWorldmeter confirmadoOURWORLD  \
# 0                       Feb 23            23-02-2020              235.0
# 1                       Mar 07            07-03-2020              277.0
# 2                       Jan 26            26-01-2020            73522.0
# 3                       Mar 01            01-03-2020              428.0
# 4                       Mar 19            19-03-2020                8.0
# ..                         ...                   ...                ...
# 230                        NaN                   NaN               81.0
# 231                        NaN                   NaN                NaN
# 232                     Feb 04            04-02-2020                NaN
# 233                     Mar 26            26-03-2020                NaN
# 234                        NaN                   NaN                NaN
#
#     muertosOURWORLD confirmadoJHON muertosJHON recuperadosJHON activosJHON
# 0               4.0          273.0         6.0            10.0       257.0
# 1              16.0          277.0        16.0            76.0       185.0
# 2             872.0        84794.0      1107.0         22440.0     61247.0
# 3              15.0          428.0        15.0            10.0       403.0
# 4               2.0            8.0         2.0             1.0         5.0
# ..              ...            ...         ...             ...         ...
# 230             2.0            NaN         NaN             NaN         NaN
# 231             NaN            NaN         NaN             NaN         NaN
# 232             NaN          712.0        11.0           619.0        82.0
# 233             NaN            9.0         2.0             0.0         7.0
# 234             NaN            NaN         NaN             NaN         NaN
#
# [235 rows x 37 columns]

# %%
data_jhon = pd.read_csv("../Johns_Hopkins-covid19/diario/ultimoRegistro.csv")
data_jhon

paises = []
confirmados = []
muertes = []
recuperados = []
activos = []
for i in data_jhon["Country_Region"].unique():
    maximoConfirmado = sum(data_jhon[data_jhon["Country_Region"] == i]["Confirmed"])
    maximoMuerte = sum(data_jhon[data_jhon["Country_Region"] == i]["Deaths"])
    maximoRecuperado = sum(data_jhon[data_jhon["Country_Region"] == i]["Recovered"])
    maximoActivo = sum(data_jhon[data_jhon["Country_Region"] == i]["Active"])
    #print(i + " " + str(maximo))
    paises.append(i)
    confirmados.append(maximoConfirmado)
    muertes.append(maximoMuerte)
    recuperados.append(maximoRecuperado)
    activos.append(maximoActivo)
    
data_jhon_salida = pd.DataFrame({
    "paises": paises,
    "confirmadoJHON":confirmados,
    "muertosJHON": muertes,
    "recuperadosJHON": recuperados,
    "activosJHON": activos
}
)
merged_left = pd.merge(left=merged_left, right=data_jhon_salida, how='left', left_on='JHONH_Country/Region', right_on='paises')
del merged_left["paises"] 
merged_left
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'paises'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-2cf0a1a93eba> in <module>
#      28 )
#      29 merged_left = pd.merge(left=merged_left, right=data_jhon_salida, how='left', left_on='JHONH_Country/Region', right_on='paises')
# ---> 30 del merged_left["paises"]
#      31 merged_left
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3757             # there was no match, this call should raise the appropriate
#    3758             # exception:
# -> 3759             self._data.delete(key)
#    3760
#    3761         # delete from the caches
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in delete(self, item)
#    1000         Delete selected item (items if non-unique) in-place.
#    1001         """
# -> 1002         indexer = self.items.get_loc(item)
#    1003
#    1004         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'paises'

# %%
data_ourworld
# Out:
#           paises  confirmadoOURWORLD  muertosOURWORLD
# 0    Afghanistan                 235                4
# 1        Albania                 277               16
# 2        Algeria                 847               58
# 3        Andorra                 428               15
# 4         Angola                   8                2
# ..           ...                 ...              ...
# 199    Venezuela                 144                3
# 200      Vietnam                 239                0
# 201        World             1000249            51515
# 202       Zambia                  39                1
# 203     Zimbabwe                   8                1
#
# [204 rows x 3 columns]
