# %%
import time
import datetime

# %%
def darhora():
    now = datetime.datetime.now()
    hora = now.strftime("%H:%M")
    if(hora == "12:35"):
        print(hora)
    else:
        print("Nop")
    time.sleep(5)
    darhora()

# %%
darhora()
# Out:
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# Nop
# ...

# %%
import Actualizar as A

# %%
A.Ciclo()
