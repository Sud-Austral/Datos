# %%
import pandas as pd

# %%
#pd.read_json("https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/Cuarentenas/Cuarentenas-Geo.geojson")
import geopandas as gpd

# %%
import geopandas as gpd
import pandas as pd

fname = "https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/Cuarentenas/Cuarentenas-Geo.geojson"

states = gpd.read_file(fname)
#print(states.head())
#states = states.to_json()
#import geojsonio
#geojsonio.display(states)
#
#map_data = states

#data = pd.from_dict(states)
#data

#states.to_csv("Mutantes.csv")
#for i in states.geometry:
#    print(i)
#    print("*****************************************************************")
    
    
type(states)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
from shapely.geometry import Point
patch = states.geometry[1]
patch
patch.area


for i in states.geometry:
    print(i)
    print("*********************************************************")
# Out:
# POLYGON ((-70.3229560000199 -18.4792109999935, -70.3235030003661 -18.4786890002327, -70.32493500026889 -18.4795480002599, -70.3257219999163 -18.4803019999812, -70.3261660003303 -18.4815849999265, -70.32628799963069 -18.4821550000826, -70.3259810003824 -18.4829700002196, -70.32555200003701 -18.484964999783, -70.3257019998248 -18.4877930003627, -70.32651699995959 -18.4897060003398, -70.3254869997397 -18.4909380001467, -70.3249720000789 -18.4929009996558, -70.3251650004227 -18.4939999998029, -70.3253520000205 -18.4947060001134, -70.3250659997902 -18.4955339995742, -70.3259970002759 -18.4958880000607, -70.32679899999189 -18.4953249997834, -70.3267000002577 -18.4945999999386, -70.3262600000417 -18.4939390003671, -70.3261420000409 -18.4933389996199, -70.32711299981131 -18.4927540001054, -70.3273189996756 -18.4932750003136, -70.327743999823 -18.4936479999946, -70.32855599958479 -18.4935320001123, -70.3285239997977 -18.4927819996238, -70.3294419998646 -18.4916949996863, -70.3295079999869 -18
# ...

# %%
from geojsonio import display

with open("Chile/MinCiencia/Input-minCiencia/Cuarentenas/Cuarentenas-Geo.geojson") as f:
    contents = f.read()
    display(contents)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationFailed                      Traceback (most recent call last)
# <ipython-input-18-5b02caec5116> in <module>
#       3 with open("Chile/MinCiencia/Input-minCiencia/Cuarentenas/Cuarentenas-Geo.geojson") as f:
#       4     contents = f.read()
# ----> 5     display(contents)
#
# C:\ProgramData\Anaconda3\lib\site-packages\geojsonio\geojsonio.py in display(contents, domain, force_gist)
#      34
#      35     """
# ---> 36     url = make_url(contents, domain, force_gist)
#      37     webbrowser.open(url)
#      38     return url
#
# C:\ProgramData\Anaconda3\lib\site-packages\geojsonio\geojsonio.py in make_url(contents, domain, force_gist, size_for_gist)
#      91         url = data_url(contents, domain)
#      92     else:
# ---> 93         gist = _make_gist(contents)
#      94         url = gist_url(gist.id, domain)
#      95
#
# ...

# %%
# Cargar la capa temática
natalidad = "Chile/MinCiencia/Input-minCiencia/Cuarentenas/Cuarentenas-Geo.geojson"
map_data = gpd.read_file(natalidad)
map_data.head()

# Control del tamaño de la figura del mapa
#fig, ax = plt.subplots()
 

 
# Mostrar el mapa finalizado
#map_data.plot(column='NAT2018', cmap='plasma', ax=ax, zorder=5)
#map_data.plot()
# Out:
#    CuarentenaID                   Nombre  Estado  Alcance        FInicio  \
# 0             1                    Arica       1        2  1587088800000
# 1             2           Santiago Norte       1        4  1586768400000
# 2             3     Puente Alto Poniente       1        4  1586484000000
# 3             4                El Bosque       1        1  1587088800000
# 4             5  San Bernardo Nororiente       1        4  1587088800000
#
#         FTermino  Cut_Com                                            Detalle  \
# 0  1588903200000    15101  Corresponde al Radio Urbano de la Ciudad de Ar...
# 1  1588903200000    13101  Corresponde a la extensión de la cuarentena en...
# 2  1588903200000    13201  Corresponde al sector delimitado por la Av. Co...
# 3  1588903200000    13105                                               None
# 4  1588903200000    13401  Corresponde al sector delimitado por los limit...
#
#    Shape__Length   Shape__Area  \
# ...

# %%
from matplotlib import pyplot
from shapely.geometry import LineString
from descartes import PolygonPatch

# %%
patch2b = PolygonPatch(map_data.geometry)
ax.add_patch(patch2b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-6b213868b7d0> in <module>
# ----> 1 patch2b = PolygonPatch(map_data.geometry)
#       2 ax.add_patch(patch2b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\descartes\patch.py in PolygonPatch(polygon, **kwargs)
#      85
#      86     """
# ---> 87     return PathPatch(PolygonPath(polygon), **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\descartes\patch.py in PolygonPath(polygon)
#      41     if hasattr(polygon, 'geom_type'):  # Shapely
#      42         ptype = polygon.geom_type
# ---> 43         if ptype == 'Polygon':
#      44             polygon = [Polygon(polygon)]
#      45         elif ptype == 'MultiPolygon':
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# ...

# %%
states
# Out:
#     CuarentenaID                   Nombre  Estado  Alcance        FInicio  \
# 0              1                    Arica       1        2  1587088800000
# 1              2           Santiago Norte       1        4  1586768400000
# 2              3     Puente Alto Poniente       1        4  1586484000000
# 3              4                El Bosque       1        1  1587088800000
# 4              5  San Bernardo Nororiente       1        4  1587088800000
# 5              6                  Chillán       2        2  1585616400000
# 6              8                   Osorno       1        2  1585616400000
# 7              9             Punta Arenas       1        2  1585789200000
# 8             10           Nueva Imperial       2        2  1586484000000
# 9             11             Lo Barnechea       2        2  1585270800000
# 10            12                 Vitacura       2        1  1585270800000
# 11            13               Las Condes       2        1  1585270800000
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Control del tamaño de la figura del mapa
fig, ax = plt.subplots(figsize=(10, 10))
 
# Control del título y los ejes
ax.set_title('Natalidad por Provincias en España, 2018', 
             pad = 20, 
             fontdict={'fontsize':20, 'color': '#4873ab'})
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
 
# Mostrar el mapa finalizado
map_data.plot(column='Alcance', cmap='plasma', ax=ax, zorder=5)

# %%
# Importamos lo ya usual.
import matplotlib.pyplot as plt
import matplotlib.cm
import pandas as pd
import numpy as np
import seaborn

# Algunas librerias extra que usaremos
from matplotlib.colors import Normalize
import matplotlib.colors as colors
from numpy import array
from numpy import max

# Aqui cargamos Basemap
from mpl_toolkits import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection


#sns.set(style="white", color_codes=True)

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-83-262d2699112a> in <module>
#      13
#      14 # Aqui cargamos Basemap
# ---> 15 from mpl_toolkits import Basemap
#      16 from matplotlib.patches import Polygon
#      17 from matplotlib.collections import PatchCollection
#
# ImportError: cannot import name 'Basemap' from 'mpl_toolkits' (unknown location)

# %%
import os
import folium

m = folium.Map(location=[41, -71], zoom_start=4)

kw = {
    'prefix': 'fa',
    'color': 'green',
    'icon': 'arrow-up'
}

angle = 180
icon = folium.Icon(angle=angle, **kw)
folium.Marker(location=[41, -72], icon=icon, tooltip=str(angle)).add_to(m)

angle = 45
icon = folium.Icon(angle=angle, **kw)
folium.Marker(location=[41, -75], icon=icon, tooltip=str(angle)).add_to(m)

angle = 90
icon = folium.Icon(angle=angle, **kw)
folium.Marker([41, -78], icon=icon, tooltip=str(angle)).add_to(m)

#m.save(os.path.join('results', 'Rotate_icon.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maploc = folium.Map(tiles="Stamen Toner")

#folium.GeoJson()

folium.GeoJson(
    "https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/Cuarentenas/Cuarentenas-Geo.geojson",
    name='geojson',
    style_function=lambda feature: {
        'fillColor': feature['properties']['Alcance'],
        'color' : feature['properties']['Alcance'],
        'weight' : 1,
        'fillOpacity' : 0.5,
        }
).add_to(maploc)
maploc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
