# %%
import pandas as pd

# %%
data = pd.read_excel("Catastro Fuentes COVID-19_Alim_Med_03.27_Karen.xlsx")

# %%
data.head()
# Out:
#    ID_Fuente Fuente  ID_Dato                     Categoria  \
# 0          1  Jumbo         1  Alimentacion y Medicamentos
# 1          1  Jumbo         2  Alimentacion y Medicamentos
# 2          1  Jumbo         3  Alimentacion y Medicamentos
# 3          1  Jumbo         4  Alimentacion y Medicamentos
# 4          1  Jumbo         5  Alimentacion y Medicamentos
#
#                   Descripción Fuente  Descarga Link  \
# 0  Sitio oficial supermercados Jumbo            NaN
# 1  Sitio oficial supermercados Jumbo            NaN
# 2  Sitio oficial supermercados Jumbo            NaN
# 3  Sitio oficial supermercados Jumbo            NaN
# 4  Sitio oficial supermercados Jumbo            NaN
#
#                              Descripción información Email Contacto Cobertura  \
# 0  Puntos georreferenciados de los locales (en go...            NaN  Nacional
# 1                               Horarios de atención            NaN  Nacional
# ...

# %%
data.to_csv("Catastro Fuentes COVID-19_Alim_Med_03.27_Karen.csv", index=False)
